# %%
import os

import numpy as np

# %%
path = './src/main/resources/assets/table_game/textures/item/mino/'
data,label = [],[]
for files in os.walk(path):
    for file in files:
        data=file
print(data)
# Out:
# ['uno-creeper-0.png', 'uno-creeper-1.png', 'uno-creeper-2.png', 'uno-creeper-3.png', 'uno-creeper-4.png', 'uno-creeper-5.png', 'uno-creeper-6.png', 'uno-creeper-7.png', 'uno-creeper-8.png', 'uno-creeper-9.png', 'uno-creeper-draw2.png', 'uno-creeper-reverse.png', 'uno-creeper-skip.png', 'uno-diamond-0.png', 'uno-diamond-1.png', 'uno-diamond-2.png', 'uno-diamond-3.png', 'uno-diamond-4.png', 'uno-diamond-5.png', 'uno-diamond-6.png', 'uno-diamond-7.png', 'uno-diamond-8.png', 'uno-diamond-9.png', 'uno-diamond-draw2.png', 'uno-diamond-reverse.png', 'uno-diamond-skip.png', 'uno-ocelot-0.png', 'uno-ocelot-1.png', 'uno-ocelot-2.png', 'uno-ocelot-3.png', 'uno-ocelot-4.png', 'uno-ocelot-5.png', 'uno-ocelot-6.png', 'uno-ocelot-7.png', 'uno-ocelot-8.png', 'uno-ocelot-9.png', 'uno-ocelot-draw2.png', 'uno-ocelot-reverse.png', 'uno-ocelot-skip.png', 'uno-redstone-0.png', 'uno-redstone-1.png', 'uno-redstone-2.png', 'uno-redstone-3.png', 'uno-redstone-4.png', 'uno-redstone-5.png', 'uno-redstone-6.png'
# ...

# %%
file_dir = './src/main/resources/assets/table_game/models/item/'
file_str = '{\n\"parent\": \"item/generated\",\n\"textures\": {\n\"layer0\": \"table_game:item/mino/$\"\n}\n}'

# %%
for name in data:
    nwe = name.replace(".png","")
    print(nwe+".json")
    print(file_str.replace("$",nwe))
# Out:
# uno-creeper-0.json
# {
# "parent": "item/generated",
# "textures": {
# "layer0": "table_game:item/mino/uno-creeper-0"
# }
# }
# uno-creeper-1.json
# {
# "parent": "item/generated",
# "textures": {
# "layer0": "table_game:item/mino/uno-creeper-1"
# }
# }
# uno-creeper-2.json
# {
# "parent": "item/generated",
# "textures": {
# "layer0": "table_game:item/mino/uno-creeper-2"
# }
# }
# uno-creeper-3.json
# {
# "parent": "item/generated",
# "textures": {
# "layer0": "table_game:item/mino/uno-creeper-3"
# }
# }
# uno-creeper-4.json
# {
# "parent": "item/generated",
# "textures": {
# "layer0": "table_game:item/mino/uno-creeper-4"
# }
# }
# uno-creeper-5.json
# {
# "parent": "item/generated",
# "textures": {
# "layer0": "table_game:item/mino/uno-creeper-5"
# }
# }
# uno-creeper-6.json
# {
# "parent": "item/generated",
# "textures": {
# "layer0": "table_game:item/mino/uno-creeper-6"
# }
# }
# uno-creeper-7.json
# {
# "parent": "item/generated",
# "textures": {
# ...

# %%
for name in data:
    nwe = name.replace(".png","")
    f = open(file_dir+nwe+".json", "a")
    f.write(file_str.replace("$",nwe))
    f.close()
